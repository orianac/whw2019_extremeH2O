# %%
import xarray as xr
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
ds = xr.open_dataset('/Users/Debbie/Desktop/Waterhackweek/waterhackweek_dalles_salmonfalls/waterhackweek_dalles_salmonfalls/waterhackweek_dalles_salmonfalls.nc')

# %%
ds_sel = ds.sel(gcm = 'canesm2', 
                rcp = 'rcp85', 
                downscale_method = 'maca', 
                parameters = 'calib_inverse', 
               outlets = b'TDA')

# %%
ds_sel2 = ds.sel(gcm = 'canesm2',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel3 = ds.sel(gcm = 'hadgem2-cc',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel4 = ds.sel(gcm = 'hadgem2-cc',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel5 = ds.sel(gcm = 'hadgem2-es',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel6 = ds.sel(gcm = 'hadgem2-es',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel7 = ds.sel(gcm = 'cnrm-cm5',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel8 = ds.sel(gcm = 'cnrm-cm5',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel9 = ds.sel(gcm = 'csiro-mk3-6-0',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel10 = ds.sel(gcm = 'csiro-mk3-6-0',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel11 = ds.sel(gcm = 'gfdl-esm2m',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel12 = ds.sel(gcm = 'gfdl-esm2m',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel13 = ds.sel(gcm = 'inmcm4',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel14 = ds.sel(gcm = 'inmcm4',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel15 = ds.sel(gcm = 'miroc5',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel16 = ds.sel(gcm = 'miroc5',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel17 = ds.sel(gcm = 'ipsl-cm5a-mr',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel18 = ds.sel(gcm = 'ipsl-cm5a-mr',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel19 = ds.sel(gcm = 'ccsm4',
                rcp = 'rcp45',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
ds_sel20 = ds.sel(gcm = 'ccsm4',
                rcp = 'rcp85',
                downscale_method = 'maca',
                parameters = 'calib_inverse',
                outlets = b'TDA')

# %%
#This plot shows the minimum annual flow at TDA under canes2 and rcp85
ds_sel['streamflow'].sel(time = slice('1950','2099')).to_series().resample('A').min().plot()

# %%
#This plot shows the daily minimum flow at TDA under canes2.
ds_sel['streamflow'].sel(time=slice('1970','1999')).groupby('time.dayofyear').min().plot(label='Historically')
ds_sel['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='Future - RCP 8.5')
ds_sel2['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='Future - RCP 4.5')
plt.legend()
plt.title('Minimum Daily Streamflow - canes2')
plt.xlabel('Day of Year')
plt.ylabel('Streamflow (CMS)')
# Out:
# Text(0, 0.5, 'Streamflow (CMS)')

# %%
#Min under RCP 4.5
ds_sel['streamflow'].sel(time=slice('1970','1999')).groupby('time.dayofyear').min().plot(label='Historical: 1970-1999', marker='', color='orange', linewidth=1.2, alpha=0.7)

ds_sel2['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='canesm2', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel3['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='hadgem2-cc', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel5['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='hadgem2-es', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel7['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='cnrm-cm5', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel9['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='csiro-mk3-6-0', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel11['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='gfdl-esm2m', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel13['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='inmcm4', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel15['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='miroc5', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel17['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='ipsl-cm5a-mr', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel19['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='ccsm4', marker='', color='grey', linewidth=1, alpha=0.4)
plt.title('Location: TDA', fontsize = 10)
plt.suptitle('Minimum Daily Streamflow - RCP 4.5', fontsize = 14)
plt.legend(loc=7, bbox_to_anchor=(1.6, 0.5))
plt.xlabel("Day of Year")
plt.ylabel("Streamflow (CMS)")
# Out:
# Text(0, 0.5, 'Streamflow (CMS)')

# %%
#Min under RCP 8.5
ds_sel['streamflow'].sel(time=slice('1970','1999')).groupby('time.dayofyear').min().plot(label='Historical: 1970-1999', marker='', color='orange', linewidth=1.2, alpha=0.7)
ds_sel['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='canesm2', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel4['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='hadgem2-cc', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel6['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='hadgem2-es', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel8['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='cnrm-cm5', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel10['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='csiro-mk3-6-0', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel12['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='gfdl-esm2m', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel14['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='inmcm4', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel16['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='miroc5', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel18['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='ipsl-cm5a-mr', marker='', color='grey', linewidth=1, alpha=0.4)
ds_sel20['streamflow'].sel(time=slice('2070','2099')).groupby('time.dayofyear').min().plot(label='ccsm4', marker='', color='grey', linewidth=1, alpha=0.4)
plt.title('Location: TDA', fontsize = 10)
plt.suptitle('Minimum Daily Streamflow - RCP 8.5', fontsize = 14)
plt.legend(loc=7, bbox_to_anchor=(1.6, 0.5))
plt.xlabel("Day of Year")
plt.ylabel("Streamflow (CMS)")
# Out:
# Text(0, 0.5, 'Streamflow (CMS)')
